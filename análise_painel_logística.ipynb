# %% [markdown]
# <a href="https://colab.research.google.com/github/mathuscm/analise_logistica/blob/main/an%C3%A1lise_painel_log%C3%ADstica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Relatório de Gestão de Faturamento e Logística

# %% [markdown]
# O relatório abaixo demonstra um painel de cotação de valores de uma empresa logísticas dos anos 2019 até 2021. As métricas foram calculadas a partir do número de pedidos realisados por cada empresa parceira: Americanas, Casa E Video, Casas Bahia, Magazine Luiza, Ricardo Eletro e Walmart.
#
# Este relatório objetiva de maneira direta fornecer dados sobre faturamentos, status de pedidos, qualidade de entrega dos pedidos, gestão de tempo das entregas por cada entregador até seus clientes.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Em amplitude, esté relatório destaca métricas importantes e esclarecidas em que é possível notar:
#
# * Walmart está no topo dos clientes parceiros, gerando uma receita cerca de 393 mil reais para a empresa, segido por Casas Bahia com 348 mil reais e Magazine Luiza, 286 mil reais (valor cumulativo dos três anos subsequentes);
# * No total dos 3 anos, Marcos doi o motorista com mais porcentagem de atraso nas entregas, seguido por Luiz e depois o Valdir;
# * O motorista Marcos também lidera as métricas de Produtos entregues errado e produtos danificados, seguido por João Gomes
# * Em três anos, o total de pedidos entregues dentro do prazo foi de 73,21%
